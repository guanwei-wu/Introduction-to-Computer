# %%
import os
from keras.models import Sequential, load_model
from keras.layers import Dense, Flatten, Conv2D, MaxPool2D
from keras.datasets import cifar10
from keras.utils import np_utils

from matplotlib.pyplot import imshow
import numpy as np

##Load Mnist Dataset
(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()
x_train = X_train.reshape(50000, 32, 32, 3)/255
x_test = X_test.reshape(10000, 32, 32, 3)/255

##Convert Class Vectors to Binary Class Matrics (Do one-hot encoding)
y_train = np_utils.to_categorical(Y_train)
y_test = np_utils.to_categorical(Y_test)

#print(y_train.shape)
#print(y_train[0])

##Model Construction
model = Sequential()
model.add(Conv2D(64, (3, 3), activation = 'relu'))
model.add(Conv2D(64, (3, 3), activation = 'relu'))
model.add(MaxPool2D(2, 2))
model.add(Conv2D(128, (3, 3), activation = 'relu'))
model.add(Conv2D(128, (3, 3), activation = 'relu'))
model.add(MaxPool2D(2, 2))
model.add(Flatten(input_shape = (32, 32, 1)))
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))

##Train the Model
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
model.fit(x_train, y_train, epochs = 10, batch_size = 64, verbose = 1)

model.summary()

##Test the Model
loss, accuracy = model.evaluate(x_test, y_test)
print('Loss: %s\nAccuracy: %s' % (loss, accuracy))
# Out:
# Epoch 1/10
# 50000/50000 [==============================] - 428s 9ms/step - loss: 1.4964 - accuracy: 0.4535
# Epoch 2/10
# 50000/50000 [==============================] - 429s 9ms/step - loss: 1.0281 - accuracy: 0.6377
# Epoch 3/10
# 50000/50000 [==============================] - 426s 9ms/step - loss: 0.8246 - accuracy: 0.7113
# Epoch 4/10
# 50000/50000 [==============================] - 427s 9ms/step - loss: 0.6961 - accuracy: 0.7571
# Epoch 5/10
# 50000/50000 [==============================] - 426s 9ms/step - loss: 0.6023 - accuracy: 0.7891
# Epoch 6/10
# 50000/50000 [==============================] - 425s 8ms/step - loss: 0.5273 - accuracy: 0.8143
# Epoch 7/10
# 50000/50000 [==============================] - 426s 9ms/step - loss: 0.4511 - accuracy: 0.8401
# Epoch 8/10
# 50000/50000 [==============================] - 427s 9ms/step - loss: 0.3866 - accuracy: 0.8649
# Epoch 9/10
# 50000/50000 [==============================] - 425s 8ms/step - loss: 0.3241 - accuracy: 0.8855
# Epoch 10/10
# 50000/50000 [==============================] - 424s 8ms/step - loss: 0.2785 - accuracy: 0.9006
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_20 (Conv2D)           (None, 30, 30, 64)        1792
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 12, 12, 128)       73856
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 10, 10, 128)       147584
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 5, 5, 128)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 3200)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               409728
# _________________________________________________________________
# dense_10 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 671,178
# Trainable params: 671,178
# Non-trainable params: 0
# _________________________________________________________________
# 10000/10000 [==============================] - 22s 2ms/step
# Loss: 0.8908107516765594
# Accuracy: 0.7542999982833862
